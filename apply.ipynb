# %% [markdown]
# # Subhalo Random Forest Classification

# %% [markdown]
# ## Apply Random Forest Classifier to DMO Subhalo Catalogs
#
# This notebook applies a trained random forest to identify subhalos that are likely to be disrupted in hydrodynamic runs of dark matter only zoom-in simulations. After loading a DMO subhalo catalog with appropriate features and a trained random forest classifier, the classifier is used to output disruption probabilities.

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import pickle

# %% [markdown]
# ### Load Data
#
# The user should upload the DMO subhalo catalog they wish to classify. We provide an example corresponding to the code in $\texttt{train.ipynb}$.

# %%
Halo023_properties = np.loadtxt('Halo023_properties_example.txt')

Halo023_features = pd.DataFrame(Halo023_properties)
Halo023_features = Halo023_features.rename(index=str, columns={0:"$d_{peri}$", \
                                                       1: "$a_{acc}$", \
                                                       2: "$V_{acc}$", \
                                                       3: "$M_{acc}$", \
                                                       4: "$a_{peri}$"})

Halo023_features
# Out:
#       $d_{peri}$  $a_{acc}$  $V_{acc}$     $M_{acc}$  $a_{peri}$
# 0     170.616243     0.8155  54.483148  1.713112e+10      0.9383
# 1     157.557844     0.9383  52.855967  1.372161e+10      1.0000
# 2     192.665472     0.6910  55.918359  1.797514e+10      0.7849
# 3      89.381026     0.8916  41.694235  6.440465e+09      0.9748
# 4      50.607471     0.8473  34.527324  3.258255e+09      0.9383
# 5     177.577639     0.7750  28.082589  2.116738e+09      0.9030
# 6     154.628554     0.9383  25.385856  1.967154e+09      1.0000
# 7     134.723775     0.8365  27.433545  1.877738e+09      0.9264
# 8     176.935008     0.8473  27.854052  1.546815e+09      1.0000
# 9      38.838089     0.8473  32.086552  2.179413e+09      0.9146
# 10     37.894413     0.5929  45.167992  5.484465e+09      0.6566
# 11    182.853359     0.3700  53.632992  8.523776e+09      0.3994
# 12     46.068215     0.8803  26.300003  1.674671e+09      0.9503
# 13    163.183601     0.7179  27.186725  1.621189e+09      0.7849
# 14    130.765622     0.6083  26.382276  1.200014e+09      0.6822
# 15     76.502588     0.6320  28.951029  1.193329e+09      0.7088
# 16     20.148839     0.7554  31.803166  1.285252e+09      0.8365
# 17    206.900040     0.9383  26.510257  6.715399e+08      1.0000
# 18    254.851077     0.8692  19.544458  6.598406e+08      0.9503
# 19     53.576682     0.8365  21.866391  8.440210e+08      0.9146
# 20    208.885215     0.9503  15.860447  6.289210e+08      1.0000
# 21     62.162585     0.7554  24.782519  9.534930e+08      0.8473
# 22     63.681819     0.7849  23.319884  8.221266e+08      0.8692
# 23    256.112967     0.9873  20.467746  5.167748e+08      1.0000
# 24    212.143638     0.9503  18.054399  5.429311e+08      1.0000
# 25     83.478660     0.5563  26.629096  7.246045e+08      0.6320
# 26     25.367426     0.5635  35.596876  1.336227e+09      0.6240
# 27     56.283062     0.8582  20.933961  5.237944e+08      0.9503
# 28     40.562134     0.8582  23.676402  4.800056e+08      0.9748
# 29    243.774391     0.9748  17.222525  3.265776e+08      1.0000
# ...          ...        ...        ...           ...         ...
# 1275  161.123638     0.9030   1.919708  2.120916e+06      0.9873
# 1276   87.910374     0.5220   7.057213  2.120916e+07      0.5854
# 1277  132.439581     0.7651   2.614460  2.356573e+06      0.8916
# 1278  122.164123     0.9383   3.574314  2.592231e+06      1.0000
# 1279   84.953012     0.7651   2.422489  2.120916e+06      0.8155
# 1280  228.234202     0.9748   2.011123  2.238745e+06      1.0000
# 1281   76.188968     0.8803   3.967397  3.534860e+06      0.9503
# 1282  110.671757     0.5563   4.589017  7.304542e+06      0.6240
# 1283  126.511503     0.7459   2.468196  1.885259e+06      0.7459
# 1284  198.692846     0.7364   2.358499  3.299203e+06      0.8155
# 1285  149.101181     0.8582   2.093396  2.356573e+06      0.8582
# 1286   85.741554     0.8916   3.089816  2.592231e+06      1.0000
# 1287  103.697095     0.9625   2.815572  3.181374e+06      0.9873
# 1288  108.340607     0.9264   2.605318  2.356573e+06      0.9625
# 1289  100.647733     0.7950   1.682030  9.426294e+05      0.8260
# 1290  171.521750     0.9146   2.203094  1.649601e+06      1.0000
# 1291   77.021049     0.9625   2.376782  1.885259e+06      1.0000
# 1292   92.505061     0.8692   2.029406  2.356573e+06      0.9625
# 1293   81.360305     0.6650   4.653007  5.420119e+06      0.7364
# 1294  255.148545     0.9873   1.901425  2.120916e+06      1.0000
# 1295  164.148684     0.8473   3.126382  2.592231e+06      0.9503
# 1296  136.774945     0.9625   2.239660  2.238745e+06      1.0000
# 1297  176.559497     0.9625   2.193952  2.120916e+06      1.0000
# 1298   27.789034     0.7651   5.265485  1.037059e+07      0.8365
# 1299  198.007855     0.9146   2.020264  2.356573e+06      1.0000
# 1300  259.505121     0.8473   1.700313  1.178287e+06      0.8582
# 1301   65.445603     0.9146   1.928850  2.356573e+06      1.0000
# 1302   44.977895     0.7554   3.108099  4.713147e+06      0.8260
# 1303   41.046798     0.9030   1.709454  1.413944e+06      1.0000
# 1304  202.370219     0.7179   3.016684  4.477490e+06      0.7950
#
# [1305 rows x 5 columns]

# %%
#Load finalized model
filename = 'finalized_rf.sav'
loaded_model = pickle.load(open(filename, 'rb'))

# %% [markdown]
# ### Apply Random Forest Classifier

# %%
#Survival and Disruption Probabilities
prob = loaded_model.predict_proba(Halo023_features)
surv_prob = prob[:,0]
dest_prob = prob[:,1]

# %%
#Most likely classification (50% probability split)
pred = loaded_model.predict(Halo023_features)
Halo023_surviving_features = Halo023_features[pred==0]

# %%
print('Survival Fraction: %0.2f' % (len(pred[pred==0])/len(pred)))
# Out:
# Survival Fraction: 0.78
